# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinayak-Sharma12/Working_with_Pandas_with_me/blob/main/Working_with_Pandas_with_me(Part-2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Manipulation using Pandas (Part2 - Working with CSV)
#
# - Pandas is an open-source Python Library providing high-performance data manipulation and analysis tool using its powerful data structures.
#
#
#
#
# ##### Note:
# 1. First Clean the Evironment (Go to "Kernel" Menu --> "Restart & Clean Output"
# 2. To execute the code --> Click on a cell and press cntrl + enter key

# %% [markdown]
# ## <span style='color:Red'> 1. Working with data file (csv)</span>

# %% [markdown]
# ### 1.1 Read csv file

# %%
import pandas as pd

df = pd.read_csv('data14.csv')
print("type(df)-->",type(df))

df.head()
# Out:
# type(df)--> <class 'pandas.core.frame.DataFrame'>
#            id  F1    F2   F3    F4  F5       F6   F7
# 0  4519157822   0  28.0  NaN  11.0   0  17210.0  6.6
# 1  4523371949   0  12.0  NaN   5.0   0  14712.0  6.6
# 2  4521474530   0  15.0  0.0   NaN   1  16113.0  6.4
# 3  4524384067   0  43.0  0.0   NaN   1  15157.0  7.0
# 4  4436033771   0  75.0  0.0   6.0   0  16400.0  7.0

# %%
# Get the datatype of each column
df.dtypes
# Out:
# id      int64
# F1      int64
# F2    float64
# F3    float64
# F4    float64
# F5      int64
# F6    float64
# F7    float64
# dtype: object

# %%
# To read files

# To Read CSV  file  --> pd.read_csv()
# To Read Excel file --> pd.read_excel()
# To Read Json  file --> pd.read_json()
# To Read HTML  file --> pd.read_html()

# Self learning: How to read data from SQL, MongoDB, Oracle, MySQL using python

# %% [markdown]
# ### 1.2 Get the dimention of the dataset

# %%
print("df.shape -->", df.shape)
print("Rows     -->", df.shape[0])
print("Columns  -->", df.shape[1])
# Out:
# df.shape --> (12067, 8)
# Rows     --> 12067
# Columns  --> 8

# %% [markdown]
# ### 1.3 Show top 5 rows of the dataset

# %%
df.head()

# Try Also
#df.head(10)
#df.head(20)
# Out:
#            id  F1    F2   F3    F4  F5       F6   F7
# 0  4519157822   0  28.0  NaN  11.0   0  17210.0  6.6
# 1  4523371949   0  12.0  NaN   5.0   0  14712.0  6.6
# 2  4521474530   0  15.0  0.0   NaN   1  16113.0  6.4
# 3  4524384067   0  43.0  0.0   NaN   1  15157.0  7.0
# 4  4436033771   0  75.0  0.0   6.0   0  16400.0  7.0

# %% [markdown]
# ### 1.4 Show bottom 5 rows of the dataset

# %%
df.tail()

# Try Also
#df.tail(10)
#df.tail(20)
# Out:
#                id  F1    F2   F3   F4  F5       F6   F7
# 12062  4527873286   1  17.0  1.0  5.0   1  17765.0  7.2
# 12063  4527797466   1  54.0  0.0  8.0   1  16238.0  7.2
# 12064  4527713716   0  23.0  0.0  5.0   0  15903.0  7.0
# 12065  4527628313   0  14.0  1.0  3.0   1  14459.0  6.6
# 12066  4523772935   1  18.0  1.0  5.0   0  16266.0  7.0

# %%
# Question: Select rowz from 51 to 60
# Answer: df.head(61).tail(10)

# %% [markdown]
# ### 1.5 Get all column names of the dataset

# %%
df.columns

# Try Also
#len(df.columns)
# Out:
# Index(['id', 'F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7'], dtype='object')

# %% [markdown]
# ### 1.6 Get the index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12067, step=1)

# %% [markdown]
# ### 1.7 Get the statistical summary of the dataset

# %%
df.describe()
# Out:
#                  id            F1            F2            F3            F4  \
# count  1.206700e+04  12067.000000  11985.000000  12057.000000  12006.000000
# mean   4.502005e+09      0.499378     22.440801      0.506262      6.657588
# std    2.691983e+07      0.500020     18.079325      0.499982      4.074763
# min    4.295358e+09      0.000000      5.000000      0.000000      0.000000
# 25%    4.488640e+09      0.000000     14.000000      0.000000      4.000000
# 50%    4.512745e+09      0.000000     17.000000      1.000000      6.000000
# 75%    4.522339e+09      1.000000     20.000000      1.000000      9.000000
# max    4.527991e+09      1.000000    250.000000      1.000000     29.000000
#
#                  F5            F6            F7
# count  12067.000000  12059.000000  12055.000000
# mean       0.554239  16507.752384      6.915869
# std        0.626190   1534.554755      0.303914
# min        0.000000  10730.000000      4.600000
# 25%        0.000000  15420.500000      6.800000
# 50%        0.000000  16400.000000      7.000000
# 75%        1.000000  17464.500000      7.200000
# max        2.000000  23701.000000      8.000000

# %% [markdown]
# ### 1.8 Get the information related to the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12067 entries, 0 to 12066
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      12067 non-null  int64
#  1   F1      12067 non-null  int64
#  2   F2      11985 non-null  float64
#  3   F3      12057 non-null  float64
#  4   F4      12006 non-null  float64
#  5   F5      12067 non-null  int64
#  6   F6      12059 non-null  float64
#  7   F7      12055 non-null  float64
# dtypes: float64(5), int64(3)
# memory usage: 754.3 KB

# %% [markdown]
# ### 1.9 Transposing the dataset

# %%
df.T
# Out:
#            0             1             2             3             4      \
# id  4.519158e+09  4.523372e+09  4.521475e+09  4.524384e+09  4.436034e+09
# F1  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# F2  2.800000e+01  1.200000e+01  1.500000e+01  4.300000e+01  7.500000e+01
# F3           NaN           NaN  0.000000e+00  0.000000e+00  0.000000e+00
# F4  1.100000e+01  5.000000e+00           NaN           NaN  6.000000e+00
# F5  0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# F6  1.721000e+04  1.471200e+04  1.611300e+04  1.515700e+04  1.640000e+04
# F7  6.600000e+00  6.600000e+00  6.400000e+00  7.000000e+00  7.000000e+00
#
#            5             6             7             8             9      ...  \
# id  4.475366e+09  4.493011e+09  4.496759e+09  4.443048e+09  4.509433e+09  ...
# F1  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00  ...
# F2  1.800000e+01  1.800000e+01  1.600000e+01  1.600000e+01  1.300000e+01  ...
# F3  0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00  ...
# F4  6.000000e+00  7.000000e+00  3.000000e+00  8.000000e+00  5.000000e+00  ...
# F5  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00  ...
# F6  1.589900e+04  1.687400e+04  1.530500e+04  1.640100e+04           NaN  ...
# F7  7.000000e+00  6.800000e+00  6.400000e+00  7.200000e+00  6.800000e+00  ...
#
#            12057         12058         12059         12060         12061  \
# id  4.527875e+09  4.527811e+09  4.527716e+09  4.527650e+09  4.527878e+09
# F1  0.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# F2  1.200000e+01  4.600000e+01  1.200000e+01  1.200000e+01  1.800000e+01
# F3  0.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# F4  1.200000e+01  2.000000e+00  5.000000e+00  9.000000e+00  1.300000e+01
# F5  1.000000e+00  0.000000e+00  2.000000e+00  0.000000e+00  0.000000e+00
# F6  1.619800e+04  1.692300e+04  1.513100e+04  1.715500e+04  1.857300e+04
# F7  7.000000e+00  7.200000e+00  6.800000e+00  7.000000e+00  7.200000e+00
#
#            12062         12063         12064         12065         12066
# id  4.527873e+09  4.527797e+09  4.527714e+09  4.527628e+09  4.523773e+09
# F1  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# F2  1.700000e+01  5.400000e+01  2.300000e+01  1.400000e+01  1.800000e+01
# F3  1.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# F4  5.000000e+00  8.000000e+00  5.000000e+00  3.000000e+00  5.000000e+00
# F5  1.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00  0.000000e+00
# F6  1.776500e+04  1.623800e+04  1.590300e+04  1.445900e+04  1.626600e+04
# F7  7.200000e+00  7.200000e+00  7.000000e+00  6.600000e+00  7.000000e+00
#
# [8 rows x 12067 columns]

# %% [markdown]
# ### 1.10 Accessing data from dataset - Part 1 (using loc - Column Names)

# %%
# Syntax --> loc[ ROW, COL_Names_in_List ]

df.loc[:, ['F1','F3','F6']].head()

# Also Try
#df.loc[10: , ['F1','F3','F6']]
#df.loc[10:100 , ['F1','F3','F6','F7']]
# Out:
#    F1   F3       F6
# 0   0  NaN  17210.0
# 1   0  NaN  14712.0
# 2   0  0.0  16113.0
# 3   0  0.0  15157.0
# 4   0  0.0  16400.0

# %% [markdown]
# ### 1.11 Accessing data from dataset - Part 2 (using iloc - Column position)

# %%
# Syntax --> iloc[ ROW, COL_Position]

df.iloc[0:10, :5]

# Also Try
#df.iloc[10:100, :-2]
#df.iloc[20:30, 1:5]
# Out:
#            id  F1    F2   F3    F4
# 0  4519157822   0  28.0  NaN  11.0
# 1  4523371949   0  12.0  NaN   5.0
# 2  4521474530   0  15.0  0.0   NaN
# 3  4524384067   0  43.0  0.0   NaN
# 4  4436033771   0  75.0  0.0   6.0
# 5  4475365709   1  18.0  0.0   6.0
# 6  4493010632   1  18.0  1.0   7.0
# 7  4496759358   0  16.0  0.0   3.0
# 8  4443048030   0  16.0  0.0   8.0
# 9  4509433346   1  13.0  1.0   5.0

# %% [markdown]
# ### 1.12 To get unique values in a Column (factors)
# No number  in that column will be repeated in the output

# %%
#df['F1'].unique()

#len(df['F1'].unique

df['F4'].unique()

#len(df['F4'].unique())
# Out:
# array([11.,  5., nan,  6.,  7.,  3.,  8.,  1.,  4., 15., 10.,  9., 13.,
#         2., 12., 14.,  0., 18., 17., 16., 22., 21., 20., 25., 19., 23.,
#        24., 29., 28., 26., 27.])

# %% [markdown]
# ### 1.13 To get unique count  in a Column

# %%
#Used to count unique value in the columndf['F1'].value_counts()
#df['F5'].value_counts()

# %% [markdown]
# ### 1.14 Selecting data using condition - part 1

# %%
df[df['F4']>10]     # Put NaN where condition is false

#df[df['F4']>10].shape

#df[(df['F4']>20) & (df['F1'] == 1)].shape

#df[(df['F4']>20) | (df['F1'] == 1)].shape
# Out:
#                id  F1     F2   F3    F4  F5       F6   F7
# 0      4519157822   0   28.0  NaN  11.0   0  17210.0  6.6
# 12     4515594785   1   18.0  1.0  11.0   1      NaN  7.4
# 18     4486384947   1   21.0  1.0  11.0   0  16282.0  6.8
# 10639  4526469771   1  45.0  1.0  22.0   0  19551.0  7.2
# 10649  4517653649   1  93.0  0.0  27.0   0  21663.0  7.4
# 10864  4525911373   1  26.0  1.0  24.0   2  23701.0  7.8
# 11257  4502220585   1  19.0  1.0  23.0   1  22134.0  7.6
# 11598  4518264766   1  16.0  1.0  24.0   1  20289.0  7.2
# 11739  4509560405   1  15.0  0.0  22.0   1  22173.0  7.4
# 11788  4521617459   1  15.0  1.0  23.0   0  18957.0  7.4
# 11977  4524941419   1  13.0  0.0  29.0   1  23205.0  7.0

# %% [markdown]
# ### 1.18 Get the mean of the all the columns present in the dataset

# %%
df.mean()

# What is the output?
#df.head(50).mean()
#df.tail(50).mean()
# Out:
# id    4.502005e+09
# F1    4.993785e-01
# F2    2.244080e+01
# F3    5.062619e-01
# F4    6.657588e+00
# F5    5.542388e-01
# F6    1.650775e+04
# F7    6.915869e+00
# dtype: float64

# %% [markdown]
# ### 1.19 Get the correlation of the all the columns present in the dataset

# %%
df.corr()

# Note
# 1. Shows the relationship between two objects (or data columns)
# 2. Correlation value lies between -1 and +1
# 3. If correlation of two columns (Features) is greater than 0.8 (or 0.85 or 0.9),
#    then we can drop one of the column.
# Out:
#           id        F1        F2        F3        F4        F5        F6  \
# id  1.000000  0.000998  0.007969 -0.014566 -0.017172  0.021528 -0.027000
# F1  0.000998  1.000000 -0.002928  0.196676  0.272821  0.220266  0.415213
# F2  0.007969 -0.002928  1.000000 -0.003088  0.028079  0.023903  0.013745
# F3 -0.014566  0.196676 -0.003088  1.000000  0.227375  0.146028  0.308646
# F4 -0.017172  0.272821  0.028079  0.227375  1.000000  0.151771  0.748914
# F5  0.021528  0.220266  0.023903  0.146028  0.151771  1.000000  0.244700
# F6 -0.027000  0.415213  0.013745  0.308646  0.748914  0.244700  1.000000
# F7 -0.039653  0.359536  0.035232  0.176200  0.294655  0.204663  0.616570
#
#           F7
# id -0.039653
# F1  0.359536
# F2  0.035232
# F3  0.176200
# F4  0.294655
# F5  0.204663
# F6  0.616570
# F7  1.000000

# %% [markdown]
# ### 1.20 Get the maximum of each column in the dataset

# %%
df.max()
# Out:
# id    4.527991e+09
# F1    1.000000e+00
# F2    2.500000e+02
# F3    1.000000e+00
# F4    2.900000e+01
# F5    2.000000e+00
# F6    2.370100e+04
# F7    8.000000e+00
# dtype: float64

# %% [markdown]
# ### 1.21 Get the minimum of each column in the dataset

# %%
df.min()
# Out:
# id    4.295358e+09
# F1    0.000000e+00
# F2    5.000000e+00
# F3    0.000000e+00
# F4    0.000000e+00
# F5    0.000000e+00
# F6    1.073000e+04
# F7    4.600000e+00
# dtype: float64

# %% [markdown]
# ### 1.22 Get the median of each column in the dataset

# %%
df.median()
# Out:
# id    4.512745e+09
# F1    0.000000e+00
# F2    1.700000e+01
# F3    1.000000e+00
# F4    6.000000e+00
# F5    0.000000e+00
# F6    1.640000e+04
# F7    7.000000e+00
# dtype: float64

# %% [markdown]
# ### 1.23 Get the standard deviation of each column in the dataset

# %%
df.std()
# Out:
# id    2.691983e+07
# F1    5.000203e-01
# F2    1.807933e+01
# F3    4.999815e-01
# F4    4.074763e+00
# F5    6.261903e-01
# F6    1.534555e+03
# F7    3.039143e-01
# dtype: float64

# %% [markdown]
# ### 1.24 Append the dataset with the same dataset (make the vaules duplicate)

# %%
print("df.shape      -->",df.shape)

temp_df = df.append(df)

print("temp_df.shape -->",temp_df.shape)
# Out:
# df.shape      --> (12067, 8)
# temp_df.shape --> (24134, 8)
# <ipython-input-78-f959f7ff6776>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_df = df.append(df)

# %% [markdown]
# ### 1.25 Drop the duplicates present in the dataset.

# %%
print("df.shape      -->", df.shape , "Before")

temp_df = df.drop_duplicates()

print("temp_df.shape -->",temp_df.shape, " After droping duplicates")
# Out:
# df.shape      --> (12067, 8) Before
# temp_df.shape --> (9879, 8)  After droping duplicates

# %% [markdown]
# ### 1.26 IsNull: This returns true or false depending on the status of the cell

# %%
df.isnull()

# Shows True where NULL are present else False
# Out:
#           id     F1     F2     F3     F4     F5     F6     F7
# 0      False  False  False   True  False  False  False  False
# 1      False  False  False   True  False  False  False  False
# 2      False  False  False  False   True  False  False  False
# 3      False  False  False  False   True  False  False  False
# 4      False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...
# 12062  False  False  False  False  False  False  False  False
# 12063  False  False  False  False  False  False  False  False
# 12064  False  False  False  False  False  False  False  False
# 12065  False  False  False  False  False  False  False  False
# 12066  False  False  False  False  False  False  False  False
#
# [12067 rows x 8 columns]

# %% [markdown]
# ### 1.27 Aggregate of all the values which are null

# %%
df.isnull().sum()
# Out:
# id     0
# F1     0
# F2    82
# F3    10
# F4    61
# F5     0
# F6     8
# F7    12
# dtype: int64

# %% [markdown]
# ### 1.28 Drop NA values (delete rows)

# %%
# Creating new sample dataset

import pandas as pd
import numpy as np

df = pd.DataFrame({"Name":["Iron-Man","Wonder-Woman","Avengers","Ramayan"],
                     "House":["Marvel","DC Comics","Marvel","Ramanand Sagar"],
                     "Start":[np.nan, pd.Timestamp("2017-05-15"),
                              pd.NaT, pd.Timestamp("1987-01-25")]})

df
# Out:
#            Name           House      Start
# 0      Iron-Man          Marvel        NaT
# 1  Wonder-Woman       DC Comics 2017-05-15
# 2      Avengers          Marvel        NaT
# 3       Ramayan  Ramanand Sagar 1987-01-25

# %%
df.isnull()
# Out:
#     Name  House  Start
# 0  False  False   True
# 1  False  False  False
# 2  False  False   True
# 3  False  False  False

# %%
df.isnull().sum()
# Out:
# Name     0
# House    0
# Start    2
# dtype: int64

# %%
df
# Out:
#            Name           House      Start
# 0      Iron-Man          Marvel        NaT
# 1  Wonder-Woman       DC Comics 2017-05-15
# 2      Avengers          Marvel        NaT
# 3       Ramayan  Ramanand Sagar 1987-01-25

# %%
df.dropna()     # Drop those rows having any "NA"
                    # But, No change in the original Data
# Out:
#            Name           House      Start
# 1  Wonder-Woman       DC Comics 2017-05-15
# 3       Ramayan  Ramanand Sagar 1987-01-25

# %% [markdown]
# ### 1.29 Drop the columns where there are null values

# %%
df
# Out:
#            Name           House      Start
# 0      Iron-Man          Marvel        NaT
# 1  Wonder-Woman       DC Comics 2017-05-15
# 2      Avengers          Marvel        NaT
# 3       Ramayan  Ramanand Sagar 1987-01-25

# %%
df.dropna(axis = 'columns')
# Out:
#            Name           House
# 0      Iron-Man          Marvel
# 1  Wonder-Woman       DC Comics
# 2      Avengers          Marvel
# 3       Ramayan  Ramanand Sagar

# %% [markdown]
# ### 1.30 Drop the entire row and column if ALL THE VALUES are null

# %%
df
# Out:
#            Name           House      Start
# 0      Iron-Man          Marvel        NaT
# 1  Wonder-Woman       DC Comics 2017-05-15
# 2      Avengers          Marvel        NaT
# 3       Ramayan  Ramanand Sagar 1987-01-25

# %%
df.dropna(how = 'all')
# Out:
#            Name           House      Start
# 0      Iron-Man          Marvel        NaT
# 1  Wonder-Woman       DC Comics 2017-05-15
# 2      Avengers          Marvel        NaT
# 3       Ramayan  Ramanand Sagar 1987-01-25

# %% [markdown]
# ### 1.31 Drop the null values where they are present

# %%
df
# Out:
#            Name           House      Start
# 0      Iron-Man          Marvel        NaT
# 1  Wonder-Woman       DC Comics 2017-05-15
# 2      Avengers          Marvel        NaT
# 3       Ramayan  Ramanand Sagar 1987-01-25

# %%
df.dropna(how = 'any') # Similar to df.dropna()
# Out:
#            Name           House      Start
# 1  Wonder-Woman       DC Comics 2017-05-15
# 3       Ramayan  Ramanand Sagar 1987-01-25

# %% [markdown]
# ### 1.32 Fill the null values with '0'

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame([[3,np.nan,4,2],[5,2,np.nan,9],
                       [np.nan,np.nan,7,np.nan],
                       [4,np.nan,5,np.nan]],
                        columns=list('PQRS'))
df
# Out:
#      P    Q    R    S
# 0  3.0  NaN  4.0  2.0
# 1  5.0  2.0  NaN  9.0
# 2  NaN  NaN  7.0  NaN
# 3  4.0  NaN  5.0  NaN

# %%
df.fillna(0)             # Fill ALL "NA" value to "0"

# Try also: To save in the dataset
df.fillna(0, inplace= True)

# %%
df
# Out:
#      P    Q    R    S
# 0  3.0  0.0  4.0  2.0
# 1  5.0  2.0  0.0  9.0
# 2  0.0  0.0  7.0  0.0
# 3  4.0  0.0  5.0  0.0

# %% [markdown]
# ### 1.33 Replace Values

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame([[3,np.nan,4,2],[5,2,np.nan,9],
                       [np.nan,np.nan,7,np.nan],
                       [4,np.nan,5,np.nan]],
                        columns=list('PQRS'))
df
# Out:
#      P    Q    R    S
# 0  3.0  NaN  4.0  2.0
# 1  5.0  2.0  NaN  9.0
# 2  NaN  NaN  7.0  NaN
# 3  4.0  NaN  5.0  NaN

# %%
replaceValues = {'P':10,'Q':11,'R':12,'S':13}  # Replace the values columnwise

df.fillna(replaceValues)
# Out:
#       P     Q     R     S
# 0   3.0  11.0   4.0   2.0
# 1   5.0   2.0  12.0   9.0
# 2  10.0  11.0   7.0  13.0
# 3   4.0  11.0   5.0  13.0

# %% [markdown]
# ### 1.34 Fill null values only once

# %%
df.fillna(replaceValues, limit = 1)  # Replace first NA value in every column

# Try Also
# Replace first two NA value in every column and save
#df.fillna(replaceValues, limit = 2)
# Out:
#       P     Q     R     S
# 0   3.0  11.0   4.0   2.0
# 1   5.0   2.0  12.0   9.0
# 2  10.0   NaN   7.0  13.0
# 3   4.0   NaN   5.0   NaN

# %% [markdown]
# ### 1.35 Calculated the mean of column (ignore NA)

# %%
df
# Out:
#      P    Q    R    S
# 0  3.0  NaN  4.0  2.0
# 1  5.0  2.0  NaN  9.0
# 2  NaN  NaN  7.0  NaN
# 3  4.0  NaN  5.0  NaN

# %%
df['P'].mean()       # Find the mean of column 'P'
# Out:
# 4.0

# %%
df.mean()            # Find the mean of all columns
# Out:
# P    4.000000
# Q    2.000000
# R    5.333333
# S    5.500000
# dtype: float64

# %%
df.iloc[:,[1,2]].mean()            # Find the mean of 1 and 2 column
# Out:
# Q    2.000000
# R    5.333333
# dtype: float64

# %% [markdown]
# ### 1.36 Filled the missing values with the calculated mean

# %%
df
# Out:
#      P    Q    R    S
# 0  3.0  NaN  4.0  2.0
# 1  5.0  2.0  NaN  9.0
# 2  NaN  NaN  7.0  NaN
# 3  4.0  NaN  5.0  NaN

# %%
# Fill NA values in one columns with its "column mean"
mean1 = df['P'].mean()
print(mean1)
df['P'].fillna(mean1)
# Out:
# 4.0
# 0    3.0
# 1    5.0
# 2    4.0
# 3    4.0
# Name: P, dtype: float64

# %%
df
# Out:
#      P    Q    R    S
# 0  3.0  NaN  4.0  2.0
# 1  5.0  2.0  NaN  9.0
# 2  NaN  NaN  7.0  NaN
# 3  4.0  NaN  5.0  NaN

# %%
# Fill NA values in all columns with "column mean"
df.fillna(df.mean())
# Out:
#      P    Q         R    S
# 0  3.0  2.0  4.000000  2.0
# 1  5.0  2.0  5.333333  9.0
# 2  4.0  2.0  7.000000  5.5
# 3  4.0  2.0  5.000000  5.5

# %% [markdown]
# ### 1.37 Describe the dataset

# %%
df.describe()
# Out:
#          P    Q         R         S
# count  3.0  1.0  3.000000  2.000000
# mean   4.0  2.0  5.333333  5.500000
# std    1.0  NaN  1.527525  4.949747
# min    3.0  2.0  4.000000  2.000000
# 25%    3.5  2.0  4.500000  3.750000
# 50%    4.0  2.0  5.000000  5.500000
# 75%    4.5  2.0  6.000000  7.250000
# max    5.0  2.0  7.000000  9.000000

# %% [markdown]
# ### 1.38 Fill the missing values with the mean of each column

# %%
# Save in the dataset
df.fillna(df.mean(), inplace= True)
df
# Out:
#      P    Q         R    S
# 0  3.0  2.0  4.000000  2.0
# 1  5.0  2.0  5.333333  9.0
# 2  4.0  2.0  7.000000  5.5
# 3  4.0  2.0  5.000000  5.5

# %% [markdown]
# ### 1.39 Find the correlation between all the columns

# %%
df.corr()
# Out:
#           P   Q         R         S
# P  1.000000 NaN  0.436436  1.000000
# Q       NaN NaN       NaN       NaN
# R  0.436436 NaN  1.000000  0.436436
# S  1.000000 NaN  0.436436  1.000000

# %% [markdown]
# ### 1.40 Saving dataframe to csv file

# %%
df.to_csv("Test.csv")

# Open Test.csv

# %% [markdown]
# ### 1.41 Converting dataframe to array

# %%
df.iloc[:].values
# Out:
# array([[3.        , 2.        , 4.        , 2.        ],
#        [5.        , 2.        , 5.33333333, 9.        ],
#        [4.        , 2.        , 7.        , 5.5       ],
#        [4.        , 2.        , 5.        , 5.5       ]])
